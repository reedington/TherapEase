# %%
import pandas as pd
import requests
import os
import time
import numpy as np
# Out:
# c:\Users\hp\anaconda3\envs\newenv001\Lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\hp\anaconda3\envs\newenv001\Lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\hp\anaconda3\envs\newenv001\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-246-g3d31191b-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
raw_folder = os.path.join(os.getcwd(),'raw_data')
classes = os.listdir(raw_folder)

# %%
classes = [c for c in classes if c != 'images' and c != '.ipynb_checkpoints']

# %%
raw_img_folder = os.path.join(raw_folder,'images')
print(f"Folder exists : {os.path.exists(raw_img_folder)}")
if os.path.exists(raw_img_folder) == False:
    os.makedirs(raw_img_folder)
# Out:
# Folder exists : False

# %%
for c in classes:
    print(f'Scraping {c} images')
    directory = os.path.join(raw_img_folder,c)
    print(f"Folder exists : {os.path.exists(directory)}")
    if os.path.exists(directory) == False:
        print(f"create folder {directory}")
        os.makedirs(directory)
    url_folder = os.path.join(raw_folder,c)
    urls = [f for f in os.listdir(url_folder) if '.txt']
    urls_filename = os.path.join(url_folder,urls[0])
    test = pd.read_csv(urls_filename, sep=' ', header=None,names =['URL'])
    for i,f in enumerate(test.iloc[np.random.randint(0,len(test),4000)]['URL']):
        print(f'Downloading {i}/4000')
        filename = f.split('/')[-1]
        filepath = os.path.join(directory,filename)
        try:
            with open(filepath, 'wb') as g:
                g.write(requests.get(f).content)
            time.sleep(5)
        except Exception as err:
            print(err)
            time.sleep(30)
            pass
    print(f"{c} images downloaded")
# Out:
# Scraping drawings images
# Folder exists : False
# create folder c:\Windows\System32\TherapEase\nsfw-detector\raw_data\images\drawings
# ...
# [Errno 22] Invalid argument: 'c:\\Windows\\System32\\TherapEase\\nsfw-detector\\raw_data\\images\\drawings\\p8Bntzj.jpg?1'
# ...
# [Errno 22] Invalid argument: 'c:\\Windows\\System32\\TherapEase\\nsfw-detector\\raw_data\\images\\drawings\\ben-juniu-ainz2lr.jpg?1543678278'
# ...
# ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# ...
# [Errno 22] Invalid argument: 'c:\\Windows\\System32\\TherapEase\\nsfw-detector\\raw_data\\images\\drawings\\tywsgin43ki21.jpg?width=236&amp;format=pjpg&amp;auto=webp&amp;s=0697dd0af6952782f50d8643cc443a1778edd0f0'
# ...
# ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# ...
